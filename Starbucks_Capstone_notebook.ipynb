# %% [markdown]
# # Starbucks Capstone Challenge
#
# ### Introduction
#
# This data set contains simulated data that mimics customer behavior on the Starbucks rewards mobile app. Once every few days, Starbucks sends out an offer to users of the mobile app. An offer can be merely an advertisement for a drink or an actual offer such as a discount or BOGO (buy one get one free). Some users might not receive any offer during certain weeks.
#
# Not all users receive the same offer, and that is the challenge to solve with this data set.
#
# Your task is to combine transaction, demographic and offer data to determine which demographic groups respond best to which offer type. This data set is a simplified version of the real Starbucks app because the underlying simulator only has one product whereas Starbucks actually sells dozens of products.
#
# Every offer has a validity period before the offer expires. As an example, a BOGO offer might be valid for only 5 days. You'll see in the data set that informational offers have a validity period even though these ads are merely providing information about a product; for example, if an informational offer has 7 days of validity, you can assume the customer is feeling the influence of the offer for 7 days after receiving the advertisement.
#
# You'll be given transactional data showing user purchases made on the app including the timestamp of purchase and the amount of money spent on a purchase. This transactional data also has a record for each offer that a user receives as well as a record for when a user actually views the offer. There are also records for when a user completes an offer.
#
# Keep in mind as well that someone using the app might make a purchase through the app without having received an offer or seen an offer.
#
# ### Example
#
# To give an example, a user could receive a discount offer buy 10 dollars get 2 off on Monday. The offer is valid for 10 days from receipt. If the customer accumulates at least 10 dollars in purchases during the validity period, the customer completes the offer.
#
# However, there are a few things to watch out for in this data set. Customers do not opt into the offers that they receive; in other words, a user can receive an offer, never actually view the offer, and still complete the offer. For example, a user might receive the "buy 10 dollars get 2 dollars off offer", but the user never opens the offer during the 10 day validity period. The customer spends 15 dollars during those ten days. There will be an offer completion record in the data set; however, the customer was not influenced by the offer because the customer never viewed the offer.
#
# ### Cleaning
#
# This makes data cleaning especially important and tricky.
#
# You'll also want to take into account that some demographic groups will make purchases even if they don't receive an offer. From a business perspective, if a customer is going to make a 10 dollar purchase without an offer anyway, you wouldn't want to send a buy 10 dollars get 2 dollars off offer. You'll want to try to assess what a certain demographic group will buy when not receiving any offers.
#
# ### Final Advice
#
# Because this is a capstone project, you are free to analyze the data any way you see fit. For example, you could build a machine learning model that predicts how much someone will spend based on demographics and offer type. Or you could build a model that predicts whether or not someone will respond to an offer. Or, you don't need to build a machine learning model at all. You could develop a set of heuristics that determine what offer you should send to each customer (i.e., 75 percent of women customers who were 35 years old responded to offer A vs 40 percent from the same demographic to offer B, so send offer A).

# %% [markdown]
# # Data Sets
#
# The data is contained in three files:
#
# * portfolio.json - containing offer ids and meta data about each offer (duration, type, etc.)
# * profile.json - demographic data for each customer
# * transcript.json - records for transactions, offers received, offers viewed, and offers completed
#
# Here is the schema and explanation of each variable in the files:
#
# **portfolio.json**
# * id (string) - offer id
# * offer_type (string) - type of offer ie BOGO, discount, informational
# * difficulty (int) - minimum required spend to complete an offer
# * reward (int) - reward given for completing an offer
# * duration (int) - time for offer to be open, in days
# * channels (list of strings)
#
# **profile.json**
# * age (int) - age of the customer
# * became_member_on (int) - date when customer created an app account
# * gender (str) - gender of the customer (note some entries contain 'O' for other rather than M or F)
# * id (str) - customer id
# * income (float) - customer's income
#
# **transcript.json**
# * event (str) - record description (ie transaction, offer received, offer viewed, etc.)
# * person (str) - customer id
# * time (int) - time in hours since start of test. The data begins at time t=0
# * value - (dict of strings) - either an offer id or transaction amount depending on the record
#
# **Note:** If you are using the workspace, you will need to go to the terminal and run the command `conda update pandas` before reading in the files. This is because the version of pandas in the workspace cannot read in the transcript.json file correctly, but the newest version of pandas can. You can access the termnal from the orange icon in the top left of this notebook.
#
# You can see how to access the terminal and how the install works using the two images below.  First you need to access the terminal:
#
# <img src="pic1.png"/>
#
# Then you will want to run the above command:
#
# <img src="pic2.png"/>
#
# Finally, when you enter back into the notebook (use the jupyter icon again), you should be able to run the below cell without any errors.

# %%
import pandas as pd
import numpy as np
import math
import json
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn import preprocessing

# read in the json files
portfolio = pd.read_json('data/portfolio.json', orient='records', lines=True)
profile = pd.read_json('data/profile.json', orient='records', lines=True)
transcript = pd.read_json('data/transcript.json', orient='records', lines=True)

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ## Review contents of datasets and confirm validity.

# %%
portfolio.head(10)
# Out:
#    reward                      channels  difficulty  duration     offer_type  \
# 0      10       [email, mobile, social]          10         7           bogo
# 1      10  [web, email, mobile, social]          10         5           bogo
# 2       0          [web, email, mobile]           0         4  informational
# 3       5          [web, email, mobile]           5         7           bogo
# 4       5                  [web, email]          20        10       discount
# 5       3  [web, email, mobile, social]           7         7       discount
# 6       2  [web, email, mobile, social]          10        10       discount
# 7       0       [email, mobile, social]           0         3  informational
# 8       5  [web, email, mobile, social]           5         5           bogo
# 9       2          [web, email, mobile]          10         7       discount
#
#                                  id
# 0  ae264e3637204a6fb9bb56bc8210ddfd
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0
# ...

# %%
portfolio.shape
# Out:
# (10, 6)

# %%
portfolio['difficulty_reward_ratio'] = portfolio['difficulty']/portfolio['reward']
portfolio = portfolio.fillna(0)

# %% [markdown]
# Portfolio is a simple dataset containing 10 rows corresponding to different offers sent out to users.
# - id (string) - offer id
# - offer_type (string) - type of offer ie BOGO, discount, informational
# - difficulty (int) - minimum required spend to complete an offer
# - reward (int) - reward given for completing an offer
# - duration (int) - time for offer to be open, in days
# - channels (list of strings)

# %%
portfolio.groupby('offer_type')['difficulty_reward_ratio'].mean()
# Out:
# offer_type
# bogo             1.000000
# discount         4.083333
# informational    0.000000
# Name: difficulty_reward_ratio, dtype: float64

# %%
profile.describe()
# Out:
#                 age  became_member_on         income
# count  17000.000000      1.700000e+04   14825.000000
# mean      62.531412      2.016703e+07   65404.991568
# std       26.738580      1.167750e+04   21598.299410
# min       18.000000      2.013073e+07   30000.000000
# 25%       45.000000      2.016053e+07   49000.000000
# 50%       58.000000      2.017080e+07   64000.000000
# 75%       73.000000      2.017123e+07   80000.000000
# max      118.000000      2.018073e+07  120000.000000

# %%
profile.head(2)
# Out:
#   gender  age                                id  became_member_on    income
# 0   None  118  68be06ca386d4c31939f3a4f0e3dd783          20170212       NaN
# 1      F   55  0610b486422d4921ae7d2bf64640c50b          20170715  112000.0

# %%
profile.shape
# Out:
# (17000, 5)

# %%
profile.isna().mean()
# profile dataset contains null values in income and gender columns
# Out:
# gender              0.127941
# age                 0.000000
# id                  0.000000
# became_member_on    0.000000
# income              0.127941
# dtype: float64

# %%
profile.duplicated().mean()
# Out:
# 0.0

# %%
profile.gender.unique()
# Out:
# array([None, 'F', 'M', 'O'], dtype=object)

# %%
profile[profile['income'].isnull() | profile['gender'].isnull()]['age'].describe()
# it appears that rows containig null values all contain the nonsensical age of 118. It may be a bug or a default value for when nothing is entered, so I elect to remove all of these rows.
# Out:
# count    2175.0
# mean      118.0
# std         0.0
# min       118.0
# 25%       118.0
# 50%       118.0
# 75%       118.0
# max       118.0
# Name: age, dtype: float64

# %%
profile.hist(layout = (1, 3), grid = False, figsize=(15, 5));

# %% [markdown]
# Profile dataset contains demographic information of Starbucks offer app users.
# * age (int) - age of the customer
# * became_member_on (int) - date when customer created an app account
# * gender (str) - gender of the customer (note some entries contain 'O' for other rather than M or F)
# * id (str) - customer id
# * income (float) - customer's income
#
# It has 17000 rows and there are some apparent problems with the dataset: 12.7% of rows have missing values for income and gender, and there are some dubious values for age (the maximum age in the dataset is 118). Fortunately, these are the same rows and to make my analysis easier I choose to remove these rows (because infering would be impossible and losing 12.7% entries in this case is not terrible).

# %%
transcript.describe()
# Out:
#                 time
# count  306534.000000
# mean      366.382940
# std       200.326314
# min         0.000000
# 25%       186.000000
# 50%       408.000000
# 75%       528.000000
# max       714.000000

# %%
transcript.head(2)
# Out:
#                              person           event  \
# 0  78afa995795e4d85b5d9ceeca43f5fef  offer received
# 1  a03223e636434f42ac4c3df47e8bac43  offer received
#
#                                               value  time
# 0  {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0
# 1  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}     0

# %%
transcript.shape
# Out:
# (306534, 4)

# %%
transcript.isna().mean()
# Out:
# person    0.0
# event     0.0
# value     0.0
# time      0.0
# dtype: float64

# %%
transcript.event.unique()
# Out:
# array(['offer received', 'offer viewed', 'transaction', 'offer completed'],
#       dtype=object)

# %% [markdown]
# Transcript dataset contains 306534 rows representing events such as transaction, offer received, offer viewed and offer completed. It has no missing and no duplicate values.
#
# * event (str) - record description (ie transaction, offer received, offer viewed, etc.)
# * person (str) - customer id
# * time (int) - time in hours since start of test. The data begins at time t=0
# * value - (dict of strings) - either an offer id or transaction amount depending on the record

# %% [markdown]
# ## Data cleaning and feature engineering

# %% [markdown]
# My goals during data cleaning and feature engineering are to:
# * infer or remove missing values, if any
# * identify and remove/fix nonsensical values, if any
# * process categorical values via label encoding and/or one hot encoding for later use in predictive models
# * create new features if possible
#
# I will also transform all ids which are provided as hashes to simple integers for easier and more efficient analysis and joins.

# %%
def id_transformer(df, column):
    '''
    Takes in dataframe and id column (containing hash), returns df with id as integer.
    '''
    le = preprocessing.LabelEncoder()
    le.fit(df[column])
    df[column] = le.transform(df[column])
    
    return df

# %% [markdown]
# ### Portfolio

# %%
clean_portfolio = portfolio.copy()
clean_portfolio.rename(columns = {'id':'offer_id'}, inplace = True)

# %%
clean_portfolio = id_transformer(clean_portfolio, 'offer_id')

# %%
portfolio_channels_one_hot = pd.get_dummies(clean_portfolio.channels.apply(pd.Series).stack()).sum(level=0)
clean_portfolio = clean_portfolio.drop('channels', axis = 1)
clean_portfolio = clean_portfolio.join(portfolio_channels_one_hot)

# %%
clean_portfolio['offer_type'] = clean_portfolio['offer_type'].astype('category')
clean_portfolio['offer_type_codes'] = clean_portfolio['offer_type'].cat.codes

# %%
clean_portfolio
# Out:
#    reward  difficulty  duration     offer_type  offer_id  \
# 0      10          10         7           bogo         7
# 1      10          10         5           bogo         4
# 2       0           0         4  informational         3
# 3       5           5         7           bogo         6
# 4       5          20        10       discount         0
# 5       3           7         7       discount         1
# 6       2          10        10       discount         9
# 7       0           0         3  informational         5
# 8       5           5         5           bogo         8
# 9       2          10         7       discount         2
#
#    difficulty_reward_ratio  email  mobile  social  web  offer_type_codes
# 0                 1.000000      1       1       1    0                 0
# 1                 1.000000      1       1       1    1                 0
# 2                 0.000000      1       1       0    1                 2
# ...

# %% [markdown]
# ### Profile

# %%
clean_profile = profile.copy().dropna()
clean_profile.rename(columns = {'id':'customer_id'}, inplace = True)

# %%
clean_profile = id_transformer(clean_profile, 'customer_id')

# %%
clean_profile['age_bin'] = pd.cut(clean_profile['age'], bins = [17, 20, 25, 35, 60, 102], labels=['teen', 'young', 'young-adult', 'adult', 'elderly'])
clean_profile.drop('age', axis = 1, inplace = True)

# %%
clean_profile['income_bin'] = pd.cut(clean_profile['income'], bins = [29999, 49000, 64000, 80000, 120001], labels = ['Q1_income', 'Q2_income', 'Q3_income', 'Q4_income'])
clean_profile.drop('income', axis = 1, inplace = True)

# %%
clean_profile['became_member_on'] = pd.to_datetime(clean_profile['became_member_on'], format = '%Y%m%d')
clean_profile['member_on_year'] = clean_profile['became_member_on'].dt.year

# %%
clean_profile['income_bin'] = clean_profile['income_bin'].astype('category')
clean_profile['income_bin_codes'] = clean_profile['income_bin'].cat.codes

# %%
clean_profile['gender'] = clean_profile['gender'].astype('category')
clean_profile['gender_codes'] = clean_profile['gender'].cat.codes

# %%
clean_profile['age_bin'] = clean_profile['age_bin'].astype('category')
clean_profile['age_bin_codes'] = clean_profile['age_bin'].cat.codes

# %%
clean_profile.head()
# Out:
#    gender  customer_id became_member_on  age_bin income_bin  member_on_year  \
# 1       F          346       2017-07-15    adult  Q4_income            2017
# 3       F         6962       2017-05-09  elderly  Q4_income            2017
# 5       M        13107       2018-04-26  elderly  Q3_income            2018
# 8       M         3246       2018-02-09  elderly  Q2_income            2018
# 12      M         2669       2017-11-11    adult  Q2_income            2017
#
#     income_bin_codes  gender_codes  age_bin_codes
# 1                  3             0              3
# 3                  3             0              4
# 5                  2             1              4
# 8                  1             1              4
# 12                 1             1              3

# %% [markdown]
# ### Transcript

# %%
clean_transcript = transcript.copy()

# %%
def unpack(df, column, fillna=None):
    '''
    Takes dataframe, column containing a dictionary and fillna param; returns dataframe with new columns filled with dictionary values.
    '''
    ret = None
    if fillna is None:
        ret = pd.concat([df, pd.DataFrame((d for idx, d in df[column].iteritems()))], axis=1)
        del ret[column]
    else:
        ret = pd.concat([df, pd.DataFrame((d for idx, d in df[column].iteritems())).fillna(fillna)], axis=1)
        del ret[column]
    return ret

# taken from https://codereview.stackexchange.com/questions/93923/extracting-contents-of-dictionary-contained-in-pandas-dataframe-to-make-new-data

# %%
clean_transcript = unpack(clean_transcript, 'value', None)

# this works okay, but creates two columns - 'offer id' and 'offer_id', which I need to coalesce because they contain the same information

# %%
clean_transcript['offer'] = df['offer id'].combine_first(df['offer_id'])
clean_transcript.drop(['offer id', 'offer_id'], axis = 1, inplace = True)
clean_transcript.rename(columns = {'offer':'offer_id'}, inplace = True)
clean_transcript['offer_id'] = clean_transcript['offer_id'].astype('str')

# %%
clean_transcript = id_transformer(clean_transcript, 'offer_id')

# %%
clean_transcript.rename(columns = {'person':'customer_id'}, inplace = True)
clean_transcript = id_transformer(clean_transcript, 'customer_id')

# %%
clean_transcript['event'] = clean_transcript['event'].astype('category')
clean_transcript['event_codes'] = clean_transcript['event'].cat.codes

# %%
clean_transcript.head(10)
# Out:
#    customer_id           event  time  amount  reward  offer_id  event_codes
# 0         7996  offer received     0     NaN     NaN         6            1
# 1        10735  offer received     0     NaN     NaN         0            1
# 2        15043  offer received     0     NaN     NaN         2            1
# 3         9524  offer received     0     NaN     NaN         9            1
# 4         6939  offer received     0     NaN     NaN         4            1
# 5         3728  offer received     0     NaN     NaN         8            1
# 6        13108  offer received     0     NaN     NaN         1            1
# 7         3059  offer received     0     NaN     NaN         3            1
# 8        11410  offer received     0     NaN     NaN         0            1
# 9         3274  offer received     0     NaN     NaN         0            1

# %% [markdown]
# # Analysis

# %% [markdown]
# The transcript dataset contains four types of events: transaction, offer received, offer viewed and offer completed. First, I will join profile and portfolio datasets to the transcript dataset to perform exploratory analysis.

# %%
transcript_df = clean_transcript[['customer_id', 'event', 'time', 'amount', 'reward', 'offer_id']]
profile_df = clean_profile[['gender', 'customer_id', 'became_member_on', 'age_bin', 'income_bin']]
portfolio_df = clean_portfolio[['reward', 'difficulty', 'duration', 'offer_type', 'offer_id', 'difficulty_reward_ratio', 'email', 'mobile', 'social', 'web']]

# %%
analysis_df = transcript_df.merge(profile_df, how = 'left', on = 'customer_id')
analysis_df = analysis_df.merge(portfolio_df, how = 'left', on = 'offer_id')
analysis_df = analysis_df[analysis_df['event'] != "transaction"] # filter out transaction events to focus on received, viewed and completed offers

# %%
analysis_df['event'].value_counts()
# Out:
# offer received     76277
# offer viewed       57725
# offer completed    33579
# transaction            0
# Name: event, dtype: int64

# %%
analysis_df.head()
# Out:
#    customer_id           event  time  amount  reward_x  offer_id gender  \
# 0         7996  offer received     0     NaN       NaN         6      M
# 1        10735  offer received     0     NaN       NaN         0      F
# 2        15043  offer received     0     NaN       NaN         2    NaN
# 3         9524  offer received     0     NaN       NaN         9      F
# 4         6939  offer received     0     NaN       NaN         4      M
#
#   became_member_on  age_bin income_bin  reward_y  difficulty  duration  \
# 0       2015-10-11     teen  Q2_income       5.0         5.0       7.0
# 1       2017-06-15  elderly  Q1_income       5.0        20.0      10.0
# 2              NaT      NaN        NaN       2.0        10.0       7.0
# 3       2018-04-05    adult  Q2_income       2.0        10.0      10.0
# 4       2017-11-21  elderly  Q3_income      10.0        10.0       5.0
#
#   offer_type  difficulty_reward_ratio  email  mobile  social  web
# ...

# %%
analysis_df.isnull().mean()

# checking for null values, there no nulls in customer id, event, time or offer_id. some columns, e.g. reward or duration can have nulls (e.g. transaction events may not have an associated offer_id). but I need to remove rows where gender or income bins are null because these contain my previously indicated inaccurate users.
# Out:
# customer_id                0.000000
# event                      0.000000
# time                       0.000000
# amount                     1.000000
# reward_x                   0.799625
# offer_id                   0.000000
# gender                     0.128863
# became_member_on           0.128863
# age_bin                    0.128863
# income_bin                 0.128863
# reward_y                   0.000000
# difficulty                 0.000000
# duration                   0.000000
# offer_type                 0.000000
# difficulty_reward_ratio    0.000000
# email                      0.000000
# mobile                     0.000000
# social                     0.000000
# web                        0.000000
# dtype: float64

# %%
analysis_df = analysis_df.dropna(subset = ['gender'])

# %% [markdown]
# Some questions for analysis:
# * What is the distribution of offer types between income and age bins?
# * How many users receive and offer vs view an offer vs complete an offer?
# * Of users who view an offer, how many complete an offer?
# * Is the income/gender/age distribution of users who receive & not view or view & not complete an offer differ from those who view and complete an offer?

# %%
sns.countplot(x = 'gender', hue = 'offer_type', data = analysis_df[analysis_df['event'] == 'offer received'])
plt.title('Offer received by gender')
# Out:
# Text(0.5, 1.0, 'Offer received by gender')

# %%
sns.countplot(x = 'income_bin', hue = 'offer_type', data = analysis_df[analysis_df['event'] == 'offer received'])
plt.title('Offer received by income_bin')
# Out:
# Text(0.5, 1.0, 'Offer received by income_bin')

# %%
sns.countplot(x = 'age_bin', hue = 'offer_type', data = analysis_df[analysis_df['event'] == 'offer received'])
plt.title('Offer received by age_bin')
# Out:
# Text(0.5, 1.0, 'Offer received by age_bin')

# %%
sns.countplot(x = 'offer_type', hue = 'event', data = analysis_df)
plt.title('Offer events by type')
# Out:
# Text(0.5, 1.0, 'Offer events by type')

# %%
# Users who receive an offer
receivers = analysis_df[analysis_df['event'] == 'offer received']['customer_id'].nunique()
receive_count = analysis_df[analysis_df['event'] == 'offer received']['event'].count()

# Users who view an offer
viewers = analysis_df[analysis_df['event'] == 'offer viewed']['customer_id'].nunique()
view_count = analysis_df[analysis_df['event'] == 'offer viewed']['event'].count()

# Users who complete an offer
completers = analysis_df[analysis_df['event'] == 'offer completed']['customer_id'].nunique()
complete_count = analysis_df[analysis_df['event'] == 'offer completed']['event'].count()

print("{} users receive an offer (there are a total of {} offers sent out, so on average a user receives {} offers)".format(receivers, receive_count, receive_count/receivers))
print("{} users view an offer (there are a total of {} offer views, so on average a user views {} offers)".format(viewers, view_count, view_count/viewers))
print("{} users complete an offer (there are a total of {} completed offers, so on average a user completes {} offers)".format(completers, complete_count, complete_count/completers))
print("{} percent of users who receive an offer view it, and {} percent of users who view it - complete it, generally.".format(viewers/receivers*100, completers/viewers*100))
# Out:
# 14820 users receive an offer (there are a total of 66525 offers sent out, so on average a user receives 4.488866396761134 offers)
# 14686 users view an offer (there are a total of 50336 offer views, so on average a user views 3.4274819556039766 offers)
# 11119 users complete an offer (there are a total of 29125 completed offers, so on average a user completes 2.6193902329346166 offers)
# 99.09581646423752 percent of users who receive an offer view it, and 75.71156203186709 percent of users who view it - complete it, generally.

# %%
transcript_df
# Out:
#         customer_id           event  time  amount  reward  offer_id
# 0              7996  offer received     0     NaN     NaN         6
# 1             10735  offer received     0     NaN     NaN         0
# 2             15043  offer received     0     NaN     NaN         2
# 3              9524  offer received     0     NaN     NaN         9
# 4              6939  offer received     0     NaN     NaN         4
# ...             ...             ...   ...     ...     ...       ...
# 306529        12027     transaction   714    1.59     NaN        10
# 306530         6913     transaction   714    9.53     NaN        10
# 306531        10722     transaction   714    3.61     NaN        10
# 306532         7881     transaction   714    3.53     NaN        10
# 306533        12847     transaction   714    4.05     NaN        10
#
# [306534 rows x 6 columns]

# %%
transcript_df = transcript_df.merge(portfolio_df[['offer_id', 'offer_type', 'duration']], on = 'offer_id').drop('amount', axis = 1)

# %%
offer_received = transcript_df[transcript_df['event'] == 'offer received']
offer_viewed = transcript_df[transcript_df['event'] == 'offer viewed']
offer_completed = transcript_df[transcript_df['event'] == 'offer viewed']
transaction = clean_transcript[clean_transcript['event'] == 'transaction']

# %% [markdown]
# ## Response analysis

# %% [markdown]
# I assume that customers who receive an offer, view it, and complete it during its validity period "respond" to the offer, except for informational offers where there is nothing to complete. In case of informational offers, I consider that any consumption after viewing it is a "response".

# %%
offer_bogo_discount = offer_received[offer_received['offer_type'] != 'informational']
offer_informational = offer_received[offer_received['offer_type'] == 'informational']

# %%
response_bogo_discount = offer_bogo_discount.merge(offer_viewed[['customer_id', 'offer_id', 'time']], on = ['customer_id', 'offer_id'], suffixes = [None, '_viewed'])
response_bogo_discount = response_bogo_discount.merge(offer_completed[['customer_id', 'offer_id', 'time']], on = ['customer_id', 'offer_id'], suffixes = [None, '_completed'])

# %%
response_informational = offer_informational.merge(offer_viewed[['customer_id', 'offer_id', 'time']], on = ['customer_id', 'offer_id'], suffixes = [None, '_viewed'])
response_informational = response_informational.merge(transaction[['customer_id', 'time']], on = ['customer_id'], suffixes = [None, '_completed'])

# %% [markdown]
# Now that all dataframes are joined, I will create response indicators by checking if response events happened within offer duration periods.

# %%
response_bogo_discount['response_view'] = np.where(response_bogo_discount['time_viewed'] - response_bogo_discount['time'] < response_bogo_discount['duration']*24, 1, 0)
response_bogo_discount['response_completed'] = np.where(response_bogo_discount['time_completed'] - response_bogo_discount['time'] < response_bogo_discount['duration']*24, 1, 0)

# %%
response_informational['response_view'] = np.where(response_informational['time_viewed'] - response_informational['time'] < response_informational['duration']*24, 1, 0)
response_informational['response_completed'] = np.where(response_informational['time_completed'] - response_informational['time'] < response_informational['duration']*24, 1, 0)

# %%
response = pd.concat([response_bogo_discount, response_informational]) # I realise at this point that df structure is the same and there was no need to calculate separately

# %%
sns.countplot(x = 'offer_type', hue = 'response_view', data = response)

# %%
response.groupby('offer_type')['response_view'].mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-528-7f48eae9e59f> in <module>
# ----> 1 response.groupby('offer_type')['response_view'].mean()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in mean(self, *args, **kwargs)
#    1203         try:
#    1204             return self._cython_agg_general(
# -> 1205                 "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1206             )
#    1207         except GroupByError:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     886
#     887         if len(output) == 0:
# --> 888             raise DataError("No numeric types to aggregate")
#     889
#     890         return self._wrap_aggregated_output(output, names)
#
# DataError: No numeric types to aggregate

# %%
plt.figure(figsize = (10, 4))
plt.title('Response to offer by gender')
sns.countplot(x = 'segment', hue = 'gender', data = customer_segments)

# %%
plt.figure(figsize = (10, 4))
plt.title('Response to offer by income')
sns.countplot(x = 'segment', hue = 'income_bin', data = customer_segments)

# %%
plt.figure(figsize = (10, 4))
plt.title('Response to offer by income')
sns.countplot(x = 'segment', hue = 'age_bin', data = customer_segments)

# %% [markdown]
# # Model
